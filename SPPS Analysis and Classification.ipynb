# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # EDA

# %%
org = pd.read_csv('student-data-org.csv')
mat =pd.read_csv('student-data-mat.csv')
studentData=pd.concat([org,mat])
# studentData = pd.read_csv('student-data-org.csv')

# %%
studentData.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   23       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   22       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   20       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   20       U     GT3       T     4     2   health  services  ...
# 4     GP   F   21       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health absences Internal Marks End Sem. Marks  \
# 0        3     4     1     1       3        4              0             33
# 1        3     3     1     1       3        2             18             33
# 2        3     2     2     3       3        6             24             39
# 3        2     2     1     1       5        0             28             42
# 4        3     2     1     2       5        0             22             39
#
#   Final GPA Final Grade
# ...

# %%
studentData.describe()
# Out:
#                age         Medu         Fedu   traveltime    studytime  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean     21.726054     2.603448     2.387931     1.522989     1.970307
# std       1.239975     1.124907     1.099938     0.731727     0.834353
# min      20.000000     0.000000     0.000000     1.000000     1.000000
# 25%      21.000000     2.000000     1.000000     1.000000     1.000000
# 50%      22.000000     3.000000     2.000000     1.000000     2.000000
# 75%      23.000000     4.000000     3.000000     2.000000     2.000000
# max      27.000000     4.000000     4.000000     4.000000     4.000000
#
#           failures       famrel     freetime        goout         Dalc  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean      0.264368     3.935824     3.201149     3.156130     1.494253
# std       0.656142     0.933401     1.031507     1.152575     0.911714
# ...

# %%
studentData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1044 entries, 0 to 394
# Data columns (total 34 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   school          1044 non-null   object
#  1   sex             1044 non-null   object
#  2   age             1044 non-null   int64
#  3   address         1044 non-null   object
#  4   famsize         1044 non-null   object
#  5   Pstatus         1044 non-null   object
#  6   Medu            1044 non-null   int64
#  7   Fedu            1044 non-null   int64
#  8   Mjob            1044 non-null   object
#  9   Fjob            1044 non-null   object
#  10  reason          1044 non-null   object
#  11  guardian        1044 non-null   object
#  12  traveltime      1044 non-null   int64
#  13  studytime       1044 non-null   int64
#  14  failures        1044 non-null   int64
#  15  schoolsup       1044 non-null   object
#  16  famsup          1044 non-null   object
# ...

# %% [markdown]
# ## Exploratory Data Analysis
#
# **Let's explore the data!**

# %%
sns.jointplot(x='Internal Marks',y='Final GPA',data=studentData)

# %%
sns.jointplot(x='End Sem. Marks',y='Final GPA',data=studentData)

# %% [markdown]
# ** Use jointplot to create a 2D hex bin plot comparing studyTime and Final GPA.**

# %%
sns.jointplot(x='studytime',y='Final GPA',kind='hex',data=studentData)

# %% [markdown]
# **Let's explore these types of relationships across the entire data set.

# %%
sns.pairplot(studentData)

# %%
sns.heatmap(studentData.corr())
# Out:
# <AxesSubplot:>

# %%
sns.lmplot(x='Internal Marks',y='Final GPA',data=studentData)

# %%
sns.set_style('whitegrid')
ax=sns.countplot(x='sex',data=studentData,palette='bright')
# RdBu_r
ax.set_title('Gender Distribution')
# Out:
# Text(0.5, 1.0, 'Gender Distribution')

# %%
ax=sns.countplot(x = "Final GPA",hue = 'sex',data =studentData,palette='bright')
ax.set_title('Students score Male vs Female',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Students score Male vs Female')

# %%
ax=sns.countplot(x='age',data=studentData,palette='bright')
ax.set_title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
ax=sns.countplot(x='Medu',data=studentData,palette='bright')
ax.set_title('Mothers Education Distribution')
# Out:
# Text(0.5, 1.0, 'Mothers Education Distribution')

# %%
ax=sns.countplot(x = "Final Grade",hue = 'Medu',data =studentData,palette='bright')
ax.set_title('GPA WRT Mothers Education',fontsize=15)
# Out:
# Text(0.5, 1.0, 'GPA WRT Mothers Education')

# %%
ax=sns.countplot(x='Fedu',data=studentData,palette='bright')
ax.set_title('Father Education Distribution')
# Out:
# Text(0.5, 1.0, 'Father Education Distribution')

# %%
ax=sns.countplot(x = "Final Grade",hue = 'Fedu',data =studentData,palette='bright')
ax.set_title('GPA WRT Fathers Education',fontsize=15)
# Out:
# Text(0.5, 1.0, 'GPA WRT Fathers Education')

# %%
ax=sns.countplot(x='Mjob',data=studentData,palette='bright')
ax.set_title('Mother Job Distribution')
# Out:
# Text(0.5, 1.0, 'Mother Job Distribution')

# %%
ax=sns.countplot(x = "Final Grade",hue = 'Mjob',data =studentData,palette='bright')
ax.set_title('GPA WRT Mothers Job',fontsize=15)
# Out:
# Text(0.5, 1.0, 'GPA WRT Mothers Job')

# %%
ax=sns.countplot(x='Fjob',data=studentData,palette='bright')
ax.set_title('Father Job Distribution')
# Out:
# Text(0.5, 1.0, 'Father Job Distribution')

# %%
ax=sns.countplot(x = "Final Grade",hue = 'Fjob',data =studentData,palette='bright')
ax.set_title('GPA WRT Fatherss Job',fontsize=15)
# Out:
# Text(0.5, 1.0, 'GPA WRT Fatherss Job')

# %%
ax=sns.countplot(x='higher',data=studentData,palette='bright')
ax.set_title('wants to take higher education Distribution')
# Out:
# Text(0.5, 1.0, 'wants to take higher education Distribution')

# %%
ax=sns.countplot(x = "Final Grade",hue = 'higher',data =studentData,palette='bright')
ax.set_title('Wants to take higher education Vs GPA',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Wants to take higher education Vs GPA')

# %%
ax=sns.countplot(x='internet',data=studentData,palette='bright')
ax.set_title('internet access to student Distribution')
# Out:
# Text(0.5, 1.0, 'internet access to student Distribution')

# %%
ax=sns.countplot(x = "Final GPA",hue = 'internet',data =studentData,palette='bright')
ax.set_title('Internet Access Vs GPA',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Internet Access Vs GPA')

# %%
ax=sns.countplot(x = "Final Grade",hue = 'internet',data =studentData,palette='bright')
ax.set_title('Internet Access Vs GPA',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Internet Access Vs GPA')

# %%
ax = sns.barplot(x="Final Grade", y="absences", data=studentData)
ax.set_title('Final GPA vs Number of absences day')
# Out:
# Text(0.5, 1.0, 'Final GPA vs Number of absences day')

# %%
# sns.displot(data=studentData, x="" ,y='')
ax=sns.barplot(x = "Final Grade",y = "absences",hue = 'sex',data =studentData ,ci = 0)
ax.set_title('Final GPA vs Absences (ac. SEX )')
# Out:
# Text(0.5, 1.0, 'Final GPA vs Absences (ac. SEX )')

# %%
ax=sns.barplot(x = "Final Grade",y = "studytime",data =studentData ,ci = 0)
ax.set_title('Final GPA vs Study Time')
# Out:
# Text(0.5, 1.0, 'Final GPA vs Study Time')

# %%
ax=sns.countplot(x = "studytime",data =studentData)
ax.set_title('Study Time Distribution')
# Out:
# Text(0.5, 1.0, 'Study Time Distribution')

# %%
ax=sns.countplot(x = "paid",data =studentData)
ax.set_title('Paid Class Distribution')
# Out:
# Text(0.5, 1.0, 'Paid Class Distribution')

# %%
ax = sns.countplot(x="Final GPA",hue='paid',data=studentData)
ax.set_title('Extra paid classes within the course subject')
# Out:
# Text(0.5, 1.0, 'Extra paid classes within the course subject')

# %%
ax=sns.kdeplot(data=studentData, x="Walc", hue="sex", multiple="stack")
ax.set_title('Weekend Alcohol Consumption WRT Sex')
# Out:
# Text(0.5, 1.0, 'Weekend Alcohol Consumption WRT Sex')

# %%
ax=sns.kdeplot(data=studentData, x="Dalc", hue="sex", multiple="stack")
ax.set_title('Weeday Alcohol Consumption WRT Sex')
# Out:
# Text(0.5, 1.0, 'Weeday Alcohol Consumption WRT Sex')

# %%
# ax=sns.barplot(x = "Final GPA",y = "Walc",hue = 'sex',data =studentData ,ci = 0)
# # ax.set_title('Final GPA vs Absences (ac. SEX )')
ax=sns.countplot(x = "Final Grade",hue = 'Walc',data =studentData,palette='bright')
ax.set_title('Final Grade By Weekend Alcohol Consumption',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Final Grade By Weekend Alcohol Consumption')

# %%
ax=sns.countplot(x = "address",data =studentData,palette='bright')
ax.set_title('Student Address- Urban vs Rural')
# Out:
# Text(0.5, 1.0, 'Student Address- Urban vs Rural')

# %%
ax=sns.countplot(x = "Final Grade",hue = 'address',data =studentData,palette='bright')
ax.set_title('Final Grade By Weekend Alcohol Consumption',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Final Grade By Weekend Alcohol Consumption')

# %%
ax=sns.boxplot(x='Final Grade', y='goout', data=studentData, palette='hot')
ax.set_title('Go Out vs Final GPA ',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Go Out vs Final GPA ')

# %%
ax=sns.boxplot(x='activities', y='Final GPA', data=studentData, palette='hot')
ax.set_title('Extra activities vs Final GPA ',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Extra activities vs Final GPA ')

# %%
ax=sns.countplot(x = "Final Grade",hue = 'romantic',data =studentData,palette='bright')
ax.set_title('Final Grade By Romantic Relationship',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Final Grade By Romantic Relationship')

# %%
ax=sns.countplot(x = "Final Grade",hue = 'Pstatus',data =studentData,palette='bright')
ax.set_title('Final Grade By Parents Status T-Living Together , A-Apart',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Final Grade By Parents Status T-Living Together , A-Apart')

# %%
ax=sns.countplot(x = "Final Grade",hue = 'health',data =studentData,palette='bright')
ax.set_title('Final Grade By Parents Status T-Living Together , A-Apart',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Final Grade By Parents Status T-Living Together , A-Apart')
